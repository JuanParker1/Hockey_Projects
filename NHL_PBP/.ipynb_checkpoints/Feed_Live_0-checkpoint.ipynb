# %%
import json
import urllib.request
import time
import datetime
today = datetime.date.today()
import tweepy as tp
from config import consumer_key,consumer_secret,access_token,access_secret

# %%
gameid = 2021021044
gamedetail = []
starturl = 'https://statsapi.web.nhl.com/api/v1/game/'
endurl = '/feed/live.json'
auth = tp.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tp.API(auth)

# %%
# time.sleep(1200) #20 minutes
# time.sleep(2400) #40 minutes
# time.sleep(3600) #1 hour
# time.sleep(5400) #1.5 hours
# time.sleep(7200) #2 hours
# time.sleep(9000) #2.5 hours
# time.sleep(10800) #3 hours
# time.sleep(24000) #6 hours 40 minutes
time.sleep(28800)
# time.sleep(30000) #8 hours 20 minutes
# time.sleep(43200) #12 hours

# Use for delay start
pullurl = starturl + str(gameid) + endurl
pullurl
gameover = 'FALSE'
print(pullurl)
# Out:
# https://statsapi.web.nhl.com/api/v1/game/2021020962/feed/live.json

# %%
while gameid <= 2021021176:
    pullurl = starturl + str(gameid) + endurl
    with urllib.request.urlopen(pullurl) as url:
        obj = json.loads(url.read().decode())
    allPlays = obj["liveData"]["plays"]['allPlays']
    teamStats = obj["liveData"]["boxscore"]["teams"]
    game_date = obj["gameData"]["datetime"]["dateTime"]
    home_team = obj["gameData"]["teams"]["home"]["name"]
    away_team = obj["gameData"]["teams"]["away"]["name"]
    game_date = game_date.split("T")[0]
    tomorrow = today + datetime.timedelta(days = 1)
    if home_team == 'Los Angeles Kings' or away_team == 'Los Angeles Kings':
        print(f'{gameid}-{obj["gameData"]["status"]["abstractGameState"]}-{game_date}-{tomorrow} -- {home_team} vs {away_team}')
    # print(obj["gameData"]["status"]["abstractGameState"])
    x=1
    period = 1
    while gameover == "FALSE" and obj["gameData"]["status"]["abstractGameState"] != "Final" and (home_team == 'Los Angeles Kings' or away_team == 'Los Angeles Kings'):
        while gameover == 'FALSE':
            #print(x)
            #x=x+1
            pullurl = starturl + str(gameid) + endurl
            try:
                with urllib.request.urlopen(pullurl) as url:
                    obj = json.loads(url.read().decode())
            except:
                print(f'The URL is broke, bruh. Try again.')
            allPlays = obj["liveData"]["plays"]['allPlays']
            hometeamscore = 0
            awayteamscore = 0
            for play in allPlays:
                period = play['about']['ordinalNum']
                event = play['result']['event']
                timeee = play['about']['periodTimeRemaining']
                description = play['result']['description']
                if event == 'Goal':
                    if str(home_team) == 'Los Angeles Kings':
                        if play['team']['name'] == 'Los Angeles Kings':
                            hometeamscore += 1
                        else:
                            awayteamscore += 1
                    if str(home_team) != 'Los Angeles Kings':
                        if play['team']['name'] != 'Los Angeles Kings':
                            hometeamscore += 1
                        else:
                            awayteamscore += 1
                if f'Period: {period}-{timeee}, {event}' not in gamedetail:
                    gamedetail.append(f'Period: {period}-{timeee}, {event}')
                    if event == 'Period Ready' or event == 'Hit' or event == 'Giveaway' or event == 'Takeaway' or event == 'Game Scheduled':
                        print(f'NOT TWEETED---Period: {period}-{timeee}, {event}-{description}')
                        #Period Ready
                        #Giveaway
                        #Takeaway
                        #Hit
                    #elif event == 'Game Scheduled':
                        #homescore = teamStats['home']['teamStats']['teamSkaterStats']['goals']
                        #awayscore = teamStats['away']['teamStats']['teamSkaterStats']['goals']
                        #print(f'Scheduled Game: {home_team} at {away_team} #GoKingsGo')
                        #api.update_status(f'Scheduled Game: {home_team} versus {away_team} #GoKingsGo')
                        #time.sleep(8)
                    elif event == 'Period Start':
                        try:
                            api.update_status(f'Period Starting: {period} --- Score: {home_team}-{hometeamscore}, {away_team}-{awayteamscore} #GoKingsGo')
                            print(f'Period Starting: {period} --- Score: {home_team}-{hometeamscore}, {away_team}-{awayteamscore} #GoKingsGo')
                        except:
                            print(f'FAILED TO TWEET --- Period Starting: {period} --- Score: {home_team}-{hometeamscore}, {away_team}-{awayteamscore} #GoKingsGo')
                        time.sleep(8)
                        #Period Start
                    elif event == 'Faceoff' or event == 'Blocked Shot' or event == 'Stoppage' or event == 'Period Official' or event == 'Game End' or event == 'Game Official' or event == 'Shot' or event == 'Penalty' or event == 'Missed Shot' :
                        try:
                            api.update_status(f'Period: {period}-{timeee}, {event}-{description} #GoKingsGo')
                            print(f'Period: {period}-{timeee}, {event}-{description} #GoKingsGo')
                            if event == 'Game End':
                                gameover = 'TRUE'
                                gameused = gameid
                        except:
                            print(f'FAILED TO TWEET -- Period: {period}-{timeee}, {event}-{description} #GoKingsGo')
                        time.sleep(8)
                        #Faceoff
                        #Blocked Shot
                        #Shot
                        #Penalty
                        #Missed Shot
                        #Stoppage
                        #Period Official
                        #Game End
                        #Game Official
                    elif event == 'Goal':
                        try:
                            api.update_status(f'Period: {period}-{timeee}, Score: {home_team}-{hometeamscore} ~ {away_team}-{awayteamscore}, {event}-{description}, #GoKingsGo')
                            print(f'Period: {period}-{timeee}, Score: {home_team}-{hometeamscore} ~ {away_team}-{awayteamscore}, {event}-{description}, #GoKingsGo')
                        except:
                            print(f'FAILED TO TWEET --- Period: {period}-{timeee}, Score: {home_team}-{hometeamscore} ~ {away_team}-{awayteamscore}, {event}-{description}, #GoKingsGo')
                        time.sleep(8)
                        #Goal
                    elif event == 'Period End' and (period == '1st' or period == '2nd'):
                        try:
                            api.update_status(f'Period {period} End --- Score: {home_team}-{hometeamscore}, {away_team}-{awayteamscore} #GoKingsGo')
                            print(f'Period {period} End --- Score: {home_team}-{hometeamscore}, {away_team}-{awayteamscore} #GoKingsGo')
                        except:
                            print(f'FAILED TO TWEET --- Period {period} End --- Score: {home_team}-{hometeamscore}, {away_team}-{awayteamscore} #GoKingsGo')
                        time.sleep(1080)
                        #Period End
                    elif event == 'Period End' and (period == '3rd'):
                        try:
                            api.update_status(f'End of Regulation --- Score: {home_team}-{hometeamscore}, {away_team}-{awayteamscore} #GoKingsGo')
                            print(f'End of Regulation --- Score: {home_team}-{hometeamscore}, {away_team}-{awayteamscore} #GoKingsGo')
                        except:
                            print(f'FAILED TO TWEET --- End of Regulation --- Score: {home_team}-{hometeamscore}, {away_team}-{awayteamscore} #GoKingsGo')
                        time.sleep(8)
                    elif event == 'Period End' and (period == 'OT'):
                        try:
                            api.update_status(f'End of Overtime --- Score: {home_team}-{hometeamscore}, {away_team}-{awayteamscore} #GoKingsGo')
                            print(f'End of Overtime --- Score: {home_team}-{hometeamscore}, {away_team}-{awayteamscore} #GoKingsGo')
                        except:
                            print(f'FAILED TO TWEET --- End of Overtime --- Score: {home_team}-{hometeamscore}, {away_team}-{awayteamscore} #GoKingsGo')
                        time.sleep(8)
                    else:
                        time.sleep(0)
            print(f'{home_team}-{hometeamscore}, {away_team}-{awayteamscore}')
    gameid += 1
# Out:
# 2021020992-Final-2022-03-19-2022-03-27 -- Vegas Golden Knights vs Los Angeles Kings
# 2021021013-Final-2022-03-23-2022-03-27 -- Los Angeles Kings vs Nashville Predators
# 2021021027-Final-2022-03-25-2022-03-27 -- Los Angeles Kings vs Chicago Blackhawks
# 2021021044-Live-2022-03-27-2022-03-27 -- Los Angeles Kings vs Seattle Kraken
# NOT TWEETED---Period: 1st-20:00, Game Scheduled-Game Scheduled
# NOT TWEETED---Period: 1st-20:00, Period Ready-Period Ready
# Period Starting: 1st --- Score: Los Angeles Kings-0, Seattle Kraken-0 #GoKingsGo
# Period: 1st-20:00, Faceoff-Phillip Danault faceoff won against Yanni Gourde #GoKingsGo
# NOT TWEETED---Period: 1st-19:04, Takeaway-Takeaway by Jordan Spence
# NOT TWEETED---Period: 1st-18:35, Hit-Jamie Oleksiak hit Olli Maatta
# Period: 1st-18:19, Missed Shot-Quinton Byfield Wide of Net Philipp Grubauer #GoKingsGo
# Period: 1st-18:05, Missed Shot-Troy Stecher Wide of Net Philipp Grubauer #GoKingsGo
# NOT TWEETED---Period: 1st-18:01, Hit-Kole Lind hit Olli Maatta
# NOT TWEETED---Period: 1st-17:44, Hit-Jamie Oleksiak hit Gabriel Vilardi
# NOT TWEETED---Period: 1st-17:39, Giveaway-Giveaway by Carson Soucy
# Period: 1st-17:39, Shot-Troy Stecher Wrist Shot saved by Philipp Grubauer #GoKingsGo
# NOT TWEETED---Period: 1st-17:23, Hit-Will Borgen hit Arthur Kaliyev
# Period: 1st-17:13, Shot-Daniel Sprong Wrist Shot saved by Cal Petersen #GoKingsGo
# Period: 1st-17:11, Stoppage-Goalie Stopped #GoKingsGo
# Period: 1st-17:11, Faceoff-Blake Lizotte faceoff won against Riley Sheahan #GoKingsGo
# NOT TWEETED---Period: 1st-17:01, Giveaway-Giveaway by Arthur Kaliyev
# Period: 1st-16:58, Stoppage-High Stick #GoKingsGo
# Period: 1st-16:58, Faceoff-Phillip Danault faceoff won against Yanni Gourde #GoKingsGo
# NOT TWEETED---Period: 1st-16:35, Hit-Trevor Moore hit Victor Rask
# Period: 1st-16:05, Stoppage-Icing #GoKingsGo
# Period: 1st-16:05, Faceoff-Anze Kopitar faceoff won against Alex Wennberg #GoKingsGo
# Period: 1st-15:54, Shot-Jordan Spence Snap Shot saved by Philipp Grubauer #GoKingsGo
# Period: 1st-15:29, Blocked Shot-Adrian Kempe shot blocked shot by Alex Wennberg #GoKingsGo
# Period: 1st-15:25, Missed Shot-Jacob Moverare Goalpost Philipp Grubauer #GoKingsGo
# NOT TWEETED---Period: 1st-15:03, Hit-Rasmus Kupari hit Will Borgen
# NOT TWEETED---Period: 1st-14:41, Giveaway-Giveaway by Derrick Pouliot
# Period: 1st-14:38, Missed Shot-Quinton Byfield Wide of Net Philipp Grubauer #GoKingsGo
# Period: 1st-14:37, Stoppage-Puck in Netting #GoKingsGo
# Period: 1st-04:55, Score: Los Angeles Kings-1 ~ Seattle Kraken-0, Goal-Gabriel Vilardi (2) Tip-In, assists: Olli Maatta (5), #GoKingsGo
# Period: 1st-04:55, Faceoff-Quinton Byfield faceoff won against Morgan Geekie #GoKingsGo
# NOT TWEETED---Period: 1st-04:34, Giveaway-Giveaway by Gabriel Vilardi
# NOT TWEETED---Period: 1st-04:32, Hit-Troy Stecher hit Jared McCann
# NOT TWEETED---Period: 1st-04:24, Hit-Will Borgen hit Quinton Byfield
# Period: 1st-03:57, Blocked Shot-Will Borgen shot blocked shot by Carl Grundstrom #GoKingsGo
# Period: 1st-03:41, Shot-Arthur Kaliyev Wrist Shot saved by Philipp Grubauer #GoKingsGo
# Period: 1st-03:36, Missed Shot-Sean Durzi Wide of Net Philipp Grubauer #GoKingsGo
# Period: 1st-03:27, Blocked Shot-Riley Sheahan shot blocked shot by Sean Durzi #GoKingsGo
# NOT TWEETED---Period: 1st-03:18, Giveaway-Giveaway by Sean Durzi
# Period: 1st-03:16, Missed Shot-Carson Soucy Wide of Net Cal Petersen #GoKingsGo
# NOT TWEETED---Period: 1st-02:59, Hit-Karson Kuhlman hit Blake Lizotte
# Period: 1st-02:40, Shot-Victor Rask Wrist Shot saved by Cal Petersen #GoKingsGo
# Period: 1st-02:37, Missed Shot-Yanni Gourde Wide of Net Cal Petersen #GoKingsGo
# NOT TWEETED---Period: 1st-02:09, Hit-Jordan Eberle hit Viktor Arvidsson
# Period: 1st-02:08, Shot-Jamie Oleksiak Slap Shot saved by Cal Petersen #GoKingsGo
# Period: 1st-02:07, Stoppage-Goalie Stopped #GoKingsGo
# Period: 1st-02:07, Faceoff-Anze Kopitar faceoff won against Kole Lind #GoKingsGo
# Period: 1st-01:19, Blocked Shot-Adrian Kempe shot blocked shot by Will Borgen #GoKingsGo
# Period: 1st-01:18, Shot-Troy Stecher Backhand saved by Philipp Grubauer #GoKingsGo
# Period: 1st-01:17, Stoppage-Goalie Stopped #GoKingsGo
# Period: 1st-01:17, Faceoff-Quinton Byfield faceoff won against Alex Wennberg #GoKingsGo
# Period: 1st-01:14, Blocked Shot-Gabriel Vilardi shot blocked shot by Jordan Eberle #GoKingsGo
# NOT TWEETED---Period: 1st-01:11, Hit-Rasmus Kupari hit Will Borgen
# NOT TWEETED---Period: 1st-00:47, Hit-Tobias Bjornfot hit Jordan Eberle
# Period: 1st-00:11, Shot-Phillip Danault Wrist Shot saved by Philipp Grubauer #GoKingsGo
# Period 1st End --- Score: Los Angeles Kings-1, Seattle Kraken-0 #GoKingsGo
# Period: 1st-00:00, Period Official-Period Official #GoKingsGo
# NOT TWEETED---Period: 2nd-20:00, Period Ready-Period Ready
# Period Starting: 2nd --- Score: Los Angeles Kings-1, Seattle Kraken-0 #GoKingsGo
# Period: 2nd-20:00, Faceoff-Yanni Gourde faceoff won against Phillip Danault #GoKingsGo
# NOT TWEETED---Period: 2nd-19:47, Giveaway-Giveaway by Trevor Moore
# Period: 2nd-19:36, Missed Shot-Trevor Moore Wide of Net Philipp Grubauer #GoKingsGo
# Period: 2nd-19:23, Blocked Shot-Victor Rask shot blocked shot by Sean Durzi #GoKingsGo
# Period: 2nd-14:59, Faceoff-Phillip Danault faceoff won against Alex Wennberg #GoKingsGo
# NOT TWEETED---Period: 2nd-14:15, Hit-Jordan Spence hit Ryan Donato
# NOT TWEETED---Period: 2nd-14:10, Hit-Alex Wennberg hit Jacob Moverare
# NOT TWEETED---Period: 2nd-14:00, Hit-Alex Wennberg hit Jordan Spence
# Period: 2nd-13:31, Score: Los Angeles Kings-2 ~ Seattle Kraken-1, Goal-Daniel Sprong (10) Snap Shot, assists: Carson Soucy (8), #GoKingsGo
# Period: 2nd-13:31, Faceoff-Anze Kopitar faceoff won against Yanni Gourde #GoKingsGo
# Period: 2nd-12:57, Shot-Adam Larsson Wrist Shot saved by Cal Petersen #GoKingsGo
# Period: 2nd-12:56, Stoppage-Goalie Stopped #GoKingsGo
# Period: 2nd-12:56, Faceoff-Quinton Byfield faceoff won against Morgan Geekie #GoKingsGo
# Period: 2nd-12:45, Blocked Shot-Morgan Geekie shot blocked shot by Olli Maatta #GoKingsGo
# Period: 2nd-12:21, Blocked Shot-Troy Stecher shot blocked shot by Jared McCann #GoKingsGo
# Period: 2nd-11:45, Shot-Phillip Danault Tip-In saved by Philipp Grubauer #GoKingsGo
# Period: 2nd-11:44, Stoppage-Goalie Stopped #GoKingsGo
# Period: 2nd-11:44, Faceoff-Riley Sheahan faceoff won against Phillip Danault #GoKingsGo
# Period: 2nd-11:33, Missed Shot-Viktor Arvidsson Wide of Net Philipp Grubauer #GoKingsGo
# NOT TWEETED---Period: 2nd-10:55, Giveaway-Giveaway by Jordan Spence
# NOT TWEETED---Period: 2nd-10:29, Hit-Anze Kopitar hit Victor Rask
# Period: 2nd-10:20, Blocked Shot-Vince Dunn shot blocked shot by Alex Iafallo #GoKingsGo
# NOT TWEETED---Period: 2nd-10:00, Takeaway-Takeaway by Jordan Eberle
# Period: 2nd-09:45, Shot-Will Borgen Snap Shot saved by Cal Petersen #GoKingsGo
# Period: 2nd-09:44, Stoppage-Goalie Stopped #GoKingsGo
# Period: 2nd-09:44, Faceoff-Phillip Danault faceoff won against Alex Wennberg #GoKingsGo
# Period: 2nd-09:35, Shot-Jordan Eberle Wrist Shot saved by Cal Petersen #GoKingsGo
# Period: 2nd-09:34, Stoppage-Goalie Stopped #GoKingsGo
# Period: 2nd-09:34, Faceoff-Alex Wennberg faceoff won against Phillip Danault #GoKingsGo
# Period: 2nd-09:24, Shot-Carson Soucy Wrist Shot saved by Cal Petersen #GoKingsGo
# Period: 2nd-09:13, Shot-Viktor Arvidsson Slap Shot saved by Philipp Grubauer #GoKingsGo
# NOT TWEETED---Period: 2nd-08:33, Hit-Carl Grundstrom hit Will Borgen
# Period: 2nd-08:11, Shot-Jared McCann Tip-In saved by Cal Petersen #GoKingsGo
# Period: 2nd-08:00, Shot-Troy Stecher Snap Shot saved by Philipp Grubauer #GoKingsGo
# NOT TWEETED---Period: 2nd-07:56, Hit-Carl Grundstrom hit Vince Dunn
# NOT TWEETED---Period: 2nd-07:45, Hit-Quinton Byfield hit Adam Larsson
# NOT TWEETED---Period: 2nd-07:10, Hit-Carson Soucy hit Rasmus Kupari
# Period: 2nd-07:03, Stoppage-Offside #GoKingsGo
# Period: 2nd-07:03, Faceoff-Anze Kopitar faceoff won against Yanni Gourde #GoKingsGo
# NOT TWEETED---Period: 2nd-06:56, Hit-Karson Kuhlman hit Tobias Bjornfot
# Period: 2nd-06:42, Penalty-Adrian Kempe Tripping against Carson Soucy #GoKingsGo
# Period: 2nd-06:42, Faceoff-Blake Lizotte faceoff won against Ryan Donato #GoKingsGo
# Period: 2nd-05:46, Missed Shot-Anze Kopitar Wide of Net Philipp Grubauer #GoKingsGo
# NOT TWEETED---Period: 2nd-05:29, Hit-Tobias Bjornfot hit Alex Wennberg
# NOT TWEETED---Period: 2nd-05:26, Giveaway-Giveaway by Sean Durzi
# NOT TWEETED---Period: 2nd-05:17, Hit-Tobias Bjornfot hit Victor Rask
# Period: 2nd-05:05, Missed Shot-Alex Wennberg Wide of Net Cal Petersen #GoKingsGo
# Period: 2nd-04:57, Blocked Shot-Daniel Sprong shot blocked shot by Tobias Bjornfot #GoKingsGo
# NOT TWEETED---Period: 2nd-04:36, Hit-Victor Rask hit Jacob Moverare
# NOT TWEETED---Period: 2nd-04:15, Hit-Jamie Oleksiak hit Arthur Kaliyev
# Period: 2nd-04:13, Score: Los Angeles Kings-3 ~ Seattle Kraken-1, Goal-Jordan Spence (1) Slap Shot, assists: Arthur Kaliyev (10), Blake Lizotte (11), #GoKingsGo
# Period: 2nd-04:13, Faceoff-Morgan Geekie faceoff won against Quinton Byfield #GoKingsGo
# NOT TWEETED---Period: 2nd-03:51, Hit-Troy Stecher hit Morgan Geekie
# Period: 2nd-03:36, Missed Shot-Jared McCann Wide of Net Cal Petersen #GoKingsGo
# NOT TWEETED---Period: 2nd-03:32, Hit-Kole Lind hit Gabriel Vilardi
# Period: 2nd-03:12, Shot-Phillip Danault Wrist Shot saved by Philipp Grubauer #GoKingsGo
# Period: 2nd-03:11, Shot-Phillip Danault Deflected saved by Philipp Grubauer #GoKingsGo
# Period: 2nd-03:10, Blocked Shot-Viktor Arvidsson shot blocked shot by Carson Soucy #GoKingsGo
# NOT TWEETED---Period: 2nd-02:53, Hit-Tobias Bjornfot hit Riley Sheahan
# Period: 2nd-02:46, Missed Shot-Yanni Gourde Wide of Net Cal Petersen #GoKingsGo
# Period: 2nd-02:35, Shot-Yanni Gourde Tip-In saved by Cal Petersen #GoKingsGo
# Period: 2nd-02:05, Stoppage-TV timeout #GoKingsGo
# Period: 2nd-02:05, Penalty-Adam Larsson Hooking against Adrian Kempe #GoKingsGo
# Period: 2nd-02:05, Faceoff-Phillip Danault faceoff won against Riley Sheahan #GoKingsGo
# Period: 2nd-01:58, Shot-Adrian Kempe Wrist Shot saved by Philipp Grubauer #GoKingsGo
# Period: 2nd-00:39, Blocked Shot-Sean Durzi shot blocked shot by Jared McCann #GoKingsGo
# Period: 2nd-00:24, Shot-Anze Kopitar Snap Shot saved by Philipp Grubauer #GoKingsGo
# Period: 2nd-00:20, Missed Shot-Alex Iafallo Wide of Net Philipp Grubauer #GoKingsGo
# Period: 2nd-00:11, Shot-Anze Kopitar Slap Shot saved by Philipp Grubauer #GoKingsGo
# Period: 2nd-00:01, Shot-Adam Larsson Snap Shot saved by Cal Petersen #GoKingsGo
# Period 2nd End --- Score: Los Angeles Kings-3, Seattle Kraken-1 #GoKingsGo

# %%
#use to catch up to live
pullurl = starturl + str(gameid) + endurl
with urllib.request.urlopen(pullurl) as url:
        obj = json.loads(url.read().decode())
allPlays = obj["liveData"]["plays"]['allPlays']
for play in allPlays:
    if f'Period: {period}-{timeee}, {event}' not in gamedetail:
        gamedetail.append(f'Period: {period}-{timeee}, {event}')
        print(play)

# %%
import json
import urllib.request
import pandas as pd

# %%
gameid = gameused
starturl = 'https://statsapi.web.nhl.com/api/v1/game/'
endurl = '/feed/live.json'

# %%
pullurl = starturl + str(gameid) + endurl
gamelog = []
playerloggg = []
try:
    pullurl = starturl + str(gameid) + endurl
    with urllib.request.urlopen(pullurl) as url:
        obj = json.loads(url.read().decode())
    allPlays = obj["liveData"]["plays"]['allPlays']
    print(gameid)
    for play in allPlays:
        d4 = play['result']
        try:
            d4.update(play['about'])
        except:
            ok = 0
        try:
            d4.update(play["coordinates"])
        except:
            ok = 0
        try:
            for breaker in play['players']:
                d5 = breaker['player']
                d5.update(breaker)
                gamelog.append(d5)
        except:
            ok = 0
        try:
            d4.update(play["team"])
        except:
            ok = 0
        gamelog.append(d4)
        #print(d4)
#     for player in allPlays:
#         try:
#             for breaker in player['players']:
#                 d5 = breaker['player']
#                 d5.update(breaker)
#                 playerloggg.append(d5)
# #                 print(breaker['player'])
#         except:
#             ok = 1
except:
    print(f'Nope {gameid}')

# %%
df1 = pd.DataFrame(gamelog)
df1

# %%
df2 = pd.DataFrame(playerloggg)
df2

# %%
locationdf = df1[df1.x.notnull()]

# %%
locationdf.loc[(locationdf.x > 0), 'x']*=-1

# %%
locationdf.loc[(locationdf.x > 0), 'y']*=-1

# %%
# locationdf.to_csv("outputlesser.csv") 
locationdf = locationdf[locationdf["name"] == 'Los Angeles Kings']
locationdf = locationdf[locationdf["event"] != 'Faceoff']
locationdf = locationdf[locationdf["event"] != 'Hit']
locationdf = locationdf[locationdf["event"] != 'Giveaway']
locationdf = locationdf[locationdf["event"] != 'Takeaway']
locationdf = locationdf[locationdf["event"] != 'Penalty']
locationdf = locationdf[locationdf["event"] != 'Blocked Shot']

# %%
selectiondf = locationdf[["x","y","event","description","ordinalNum"]]
selectiondf

# %%
selectiondf.to_csv("Kings.csv",index=False)

# %%
locationdf = df1[df1.x.notnull()]

# %%
locationdf.loc[(locationdf.x < 0), 'x']*=-1

# %%
locationdf.loc[(locationdf.x < 0), 'y']*=-1

# %%
# locationdf.to_csv("outputlesser.csv") 
locationdf = locationdf[locationdf["name"] != 'Los Angeles Kings']
# locationdf = locationdf[locationdf["name"] != '']
locationdf = locationdf[locationdf["event"] != 'Faceoff']
locationdf = locationdf[locationdf["event"] != 'Hit']
locationdf = locationdf[locationdf["event"] != 'Giveaway']
locationdf = locationdf[locationdf["event"] != 'Takeaway']
locationdf = locationdf[locationdf["event"] != 'Penalty']
locationdf = locationdf[locationdf["event"] != 'Blocked Shot']

# %%
selectiondf = locationdf[["x","y","event","description","ordinalNum"]]
selectiondf

# %%
selectiondf.to_csv("Opponent.csv",index=False)
